# %% [markdown]
# # Linear model for the minimum-variance control

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from ControlInitFunction import ControlInitFunction

# %%
from HarrisWolpert import MinimumVarianceControl, control_learning
m = MinimumVarianceControl(dt = 0.001, n_iter = 500000,record_each = 50000,eta=0.00034)
u,record=control_learning(control_init = ControlInitFunction(m.t_T//m.dt), dt = 0.001, n_iter = 500000, record_each = 50000,eta=0.00034)

# %%
from PlotFunctions import plot_signal, plot_position, plot_velocity, plot_variance

# %%
u
# Out:
# array([  3.01478507e-01,   3.01218957e-01,   3.00930406e-01,
#          3.00609595e-01,   3.00252891e-01,   2.99856249e-01,
#          2.99415158e-01,   2.98924593e-01,   2.98378947e-01,
#          2.97771964e-01,   2.97096662e-01,   2.96345244e-01,
#          2.95508997e-01,   2.94578182e-01,   2.93541901e-01,
#          2.92387953e-01,   2.91102669e-01,   2.89670719e-01,
#          2.88074896e-01,   2.86295863e-01,   2.84311869e-01,
#          2.82098412e-01,   2.79627858e-01,   2.76868990e-01,
#          2.73786491e-01,   2.70340334e-01,   2.66485067e-01,
#          2.62168981e-01,   2.57333109e-01,   2.51910065e-01,
#          2.45822645e-01,   2.38982169e-01,   2.31286499e-01,
#          2.22617656e-01,   2.12838966e-01,   2.01791613e-01,
#          1.89290481e-01,   1.75119133e-01,   1.59023749e-01,
#          1.40705802e-01,   1.19813259e-01,   9.59300585e-02,
#          6.85636345e-02,   3.71303669e-02,  -1.34989930e-03,
#         -4.34616163e-02,  -9.21872595e-02,  -1.48666396e-01,
#         -2.14211267e-01,  -2.90299970e-01,  -1.32836805e-01,
#         -4.70183677e-02,  -9.52510827e-03,   2.58008864e-03,
#          4.28881455e-03,   3.01340930e-03,   1.57122013e-03,
#          6.50896606e-04,   2.00623122e-04,   2.66429361e-05,
#         -2.01961727e-05,  -2.15458124e-05,  -1.28392385e-05,
#         -5.68866169e-06,  -1.91555368e-06,  -4.52711963e-07,
#         -5.25319213e-08,   1.49270707e-08,   2.72008576e-08,
#          3.67904172e-08,   3.55035422e-08,   2.11798674e-08,
#          3.78294545e-09,  -6.73412337e-09,  -7.90253326e-09,
#         -3.57130665e-09,   1.03362932e-09,   2.97837363e-09,
#          2.27572102e-09,   5.11431491e-10,  -8.09136330e-10,
#         -1.10418682e-09,  -6.39743974e-10,  -2.29869552e-12,
#          3.74645251e-10,   3.88147481e-10,   1.81014998e-10,
#         -4.20285203e-11,  -1.52755844e-10,  -1.36895291e-10,
#         -5.41101990e-11,   2.47000169e-11,   5.96572851e-11,
#          5.00140986e-11,   1.83104737e-11,  -1.09665448e-11,
#         -2.47092086e-11,  -2.29458231e-11,  -1.31572515e-11,
#         -3.60666581e-12,   0.00000000e+00])

# %%
record
# Out:
#                                                  position  \
# 0       [0.0, 0.0, 0.08, 0.232, 0.4488, 0.72392, 1.051...
# 50000   [0.0, 0.0, 0.0220739001138, 0.0640501051401, 0...
# 100000  [0.0, 0.0, 0.0262989648393, 0.0762684163146, 0...
# 150000  [0.0, 0.0, 0.028357185815, 0.0822218087783, 0....
# 200000  [0.0, 0.0, 0.0293226279822, 0.0850148232754, 0...
# 250000  [0.0, 0.0, 0.0297708408359, 0.0863116980977, 0...
# 300000  [0.0, 0.0, 0.0299781348272, 0.0869115752534, 0...
# 350000  [0.0, 0.0, 0.030073862865, 0.0871886344222, 0....
# 400000  [0.0, 0.0, 0.0301180470736, 0.087316529695, 0....
# 450000  [0.0, 0.0, 0.0301384388876, 0.0873755625534, 0...
# 500000  [0.0, 0.0, 0.0301478506696, 0.0874028119573, 0...
#
#                                                    signal  \
# 0       [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, ...
# 50000   [0.220739001138, 0.221096949239, 0.22149484175...
# 100000  [0.262989648393, 0.263003831199, 0.26301969517...
# 150000  [0.28357185815, 0.283431557297, 0.283275674096...
# 200000  [0.293226279822, 0.293018301092, 0.29278714701...
# 250000  [0.297708408359, 0.297471005096, 0.29720711219...
# 300000  [0.299781348272, 0.299531190818, 0.29925310148...
# 350000  [0.30073862865, 0.300482949787, 0.300198712244...
# 400000  [0.301180470736, 0.300922402552, 0.30063550340...
# 450000  [0.301384388876, 0.30112528667, 0.300837235214...
# 500000  [0.301478506696, 0.30121895685, 0.300930406353...
#
#                                                  variance  \
# 0       [0.0, 0.0, 3.2e-06, 1.4752e-05, 3.825312e-05, ...
# 50000   [0.0, 0.0, 2.43628533117e-07, 1.12391830936e-0...
# 100000  [0.0, 0.0, 3.45817775809e-07, 1.5942572468e-06...
# 150000  [0.0, 0.0, 4.02064993674e-07, 1.85312186552e-0...
# 200000  [0.0, 0.0, 4.29908255891e-07, 1.98126742764e-0...
# 250000  [0.0, 0.0, 4.43151482037e-07, 2.04222184452e-0...
# 300000  [0.0, 0.0, 4.49344283858e-07, 2.07072753609e-0...
# 350000  [0.0, 0.0, 4.52218613812e-07, 2.08395921143e-0...
# 400000  [0.0, 0.0, 4.53548379764e-07, 2.09008111273e-0...
# 450000  [0.0, 0.0, 4.5416274929e-07, 2.0929097163e-06,...
# 500000  [0.0, 0.0, 4.54446449999e-07, 2.09421598433e-0...
#
#                                                  velocity
# 0       [0.0, 0.08, 0.152, 0.2168, 0.27512, 0.327608, ...
# 50000   [0.0, 0.0220739001138, 0.0419762050263, 0.0599...
# 100000  [0.0, 0.0262989648393, 0.0499694514753, 0.0712...
# 150000  [0.0, 0.028357185815, 0.0538646229632, 0.07680...
# 200000  [0.0, 0.0293226279822, 0.0556921952932, 0.0794...
# 250000  [0.0, 0.0297708408359, 0.0565408572618, 0.0806...
# 300000  [0.0, 0.0299781348272, 0.0569334404262, 0.0811...
# 350000  [0.0, 0.030073862865, 0.0571147715572, 0.08142...
# 400000  [0.0, 0.0301180470736, 0.0571984826214, 0.0815...
# 450000  [0.0, 0.0301384388876, 0.0572371236659, 0.0815...
# 500000  [0.0, 0.0301478506696, 0.0572549612877, 0.0816...

# %%
plot_signal(record.signal, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_position(record.position, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_velocity(record.velocity, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_variance(record.variance, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %% [markdown]
# TODO : use dt / begin with bang bang solution OK
#
# TODO :  copy the notebook OK
#
# TODO: put all functions in one script HW.py - use OO a bit like https://github.com/bicv/SHL_scripts/blob/master/shl_scripts/shl_learn.py#L9 - then just use the functions OK
#
# TODO: cache data https://github.com/bicv/SHL_scripts/blob/master/shl_scripts/shl_experiments.py#L161 , just plot OK
#
# TODO: explore parameters
#
#
# TODO: apply on aSPEM / generalized coordinates / include delays

# %% [markdown]
# TODO: utiliser un $\lambda$ pour moduler le coût en vitesse (ou est-ce qu'il s'absorbe dans la variance??)

# %% [markdown]
# TODO: montrer que c'est linéaire en $x_T$

# %% [markdown]
# TODO: essayer en rajoutant le biais ~OK fonctionne pas

# %% [markdown]
# TODO: montrer que c'est  pas linéaire en $x_T$...

# %% [markdown]
# TODO: montrer une trajectoire 2D

# %% [markdown]
# TODO: regarder la "forme" d'une saccade adaptée
