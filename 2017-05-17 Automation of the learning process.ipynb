# %% [markdown]
# # Linear model for the minimum-variance control

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from ControlInitFunction import ControlInitFunction

# %%
from HarrisWolpert import MinimumVarianceControl, control_learning
m = MinimumVarianceControl(dt = 0.002, n_iter = 200000,record_each = 10000,eta=0.0017)
u,record=control_learning(control_init = ControlInitFunction(m.t_T//m.dt), dt = 0.002, n_iter = 200000, record_each = 10000,eta=0.0017)

# %%
from PlotFunctions import plot_signal, plot_position, plot_velocity, plot_variance

# %%
u
# Out:
# array([  8.73191159e-01,   8.64436909e-01,   8.54558223e-01,
#          8.43392090e-01,   8.30747511e-01,   8.16399689e-01,
#          8.00082817e-01,   7.81481042e-01,   7.60217087e-01,
#          7.35837861e-01,   7.07796138e-01,   6.75427122e-01,
#          6.37918312e-01,   5.94270593e-01,   5.43247781e-01,
#          4.83311067e-01,   4.12533753e-01,   3.28490598e-01,
#          2.28115116e-01,   1.07517899e-01,  -3.82391779e-02,
#         -2.15411636e-01,  -4.69637340e-01,  -7.47793648e-01,
#         -1.09129071e+00,  -2.92410810e-01,  -4.87193374e-02,
#          6.28696170e-03,   9.77822349e-03,   5.29006227e-03,
#          2.14911825e-03,   7.36274045e-04,   2.17443771e-04,
#          5.48685907e-05,   1.24416235e-05,   3.34120513e-06,
#          1.14291566e-06,   1.76601472e-07,  -1.58905820e-07,
#         -9.07983180e-08,   3.73471553e-08,   6.08636349e-08,
#          1.63442898e-08,  -1.75486205e-08,  -1.68836393e-08,
# ...

# %%
record
# Out:
#                                                  position  \
# 0       [0.0, 0.0, 0.16, 0.464, 0.8976, 1.44784, 2.103...
# 10000   [0.0, 0.0, 0.049352811092, 0.144100111015, 0.2...
# 20000   [0.0, 0.0, 0.0591449269576, 0.171915037161, 0....
# 30000   [0.0, 0.0, 0.0666600006558, 0.1932992194, 0.37...
# 40000   [0.0, 0.0, 0.0722099743186, 0.209114825301, 0....
# 50000   [0.0, 0.0, 0.0762722171704, 0.22070643795, 0.4...
# 60000   [0.0, 0.0, 0.0792392181371, 0.229183368461, 0....
# 70000   [0.0, 0.0, 0.0814069506933, 0.235383955521, 0....
# 80000   [0.0, 0.0, 0.0829929324086, 0.239925419226, 0....
# 90000   [0.0, 0.0, 0.084155521762, 0.243257838409, 0.4...
# 100000  [0.0, 0.0, 0.085009622687, 0.245708276848, 0.4...
# 110000  [0.0, 0.0, 0.0856385576233, 0.247514237032, 0....
# 120000  [0.0, 0.0, 0.0861027945927, 0.248848303848, 0....
# 130000  [0.0, 0.0, 0.0864462836062, 0.24983607178, 0.4...
# 140000  [0.0, 0.0, 0.0867010323677, 0.250569113357, 0....
# ...

# %%
plot_signal(record.signal, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_position(record.position, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_velocity(record.velocity, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_variance(record.variance, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %% [markdown]
# TODO : use dt / begin with bang bang solution OK
#
# TODO :  copy the notebook OK
#
# TODO: put all functions in one script HW.py - use OO a bit like https://github.com/bicv/SHL_scripts/blob/master/shl_scripts/shl_learn.py#L9 - then just use the functions OK
#
# TODO: cache data https://github.com/bicv/SHL_scripts/blob/master/shl_scripts/shl_experiments.py#L161 , just plot ~OK
#
# TODO: explore parameters
#
#
# TODO: apply on aSPEM / generalized coordinates / include delays

# %% [markdown]
# TODO: utiliser un $\lambda$ pour moduler le coût en vitesse (ou est-ce qu'il s'absorbe dans la variance??)

# %% [markdown]
# TODO: montrer que c'est linéaire en $x_T$

# %% [markdown]
# TODO: essayer en rajoutant le biais

# %% [markdown]
# TODO: montrer que c'est  pas linéaire en $x_T$...

# %% [markdown]
# TODO: montrer une trajectoire 2D

# %% [markdown]
# TODO: regarder la "forme" d'une saccade adaptée
