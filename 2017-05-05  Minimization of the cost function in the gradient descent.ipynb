# %% [markdown]
# # Linear model for the minimum-variance control

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from ControlInitFunction import ControlInitFunction

# %%
from HarrisWolpert import MinimumVarianceControl, control_learning
m = MinimumVarianceControl(dt = 0.0025, n_iter = 100000,record_each = 5000,eta=0.003)
u,record=control_learning(control_init = ControlInitFunction(m.t_T//m.dt), dt = 0.0025, n_iter = 100000, record_each = 5000,eta=0.003)

# %%
from PlotFunctions import plot_signal, plot_position, plot_velocity, plot_variance

# %%
u
# Out:
# array([  1.17578758e+00,   1.15836944e+00,   1.13856262e+00,
#          1.11598921e+00,   1.09020076e+00,   1.06066317e+00,
#          1.02673785e+00,   9.87658503e-01,   9.42502387e-01,
#          8.90154809e-01,   8.29265436e-01,   7.58194843e-01,
#          6.74949712e-01,   5.77105406e-01,   4.61715489e-01,
#          3.25209622e-01,   1.63284920e-01,  -2.91975697e-02,
#         -1.77416136e+00,  -2.23578183e+00,  -3.17508707e-01,
#         -4.84729182e-02,   1.07849381e-02,   1.12098132e-02,
#          4.64413183e-03,   1.35310325e-03,   4.27632460e-04,
#          2.22368211e-04,   1.13695861e-04,   2.87710919e-05,
#         -9.17770855e-06,  -1.03169037e-05,  -7.70769045e-07,
#          4.21038297e-06,   3.29904751e-06,   6.03829613e-07,
#         -9.38590079e-07,  -9.81332177e-07,  -4.25804069e-07,
#         -3.44437819e-08,   0.00000000e+00])

# %%
record
# Out:
#                                                 position  \
# 0      [0.0, 0.0, 0.4346, 1.26034, 2.438106, 3.932695...
# 500    [0.0, 0.0, 0.835572042707, 2.32739262325, 4.30...
# 1000   [0.0, 0.0, 0.963038474583, 2.641851374, 4.7969...
# 1500   [0.0, 0.0, 1.05911641091, 2.87805320593, 5.165...
# 2000   [0.0, 0.0, 1.13256842378, 3.0578981708, 5.4446...
# 2500   [0.0, 0.0, 1.18963177834, 3.19696276655, 5.658...
# 3000   [0.0, 0.0, 1.23477250712, 3.30639800321, 5.825...
# 3500   [0.0, 0.0, 1.27119122972, 3.39419333043, 5.958...
# 4000   [0.0, 0.0, 1.30118436093, 3.4660792056, 6.0658...
# 4500   [0.0, 0.0, 1.32640206468, 3.52617164937, 6.154...
# 5000   [0.0, 0.0, 1.34803247817, 3.57743256509, 6.229...
# 5500   [0.0, 0.0, 1.36693328796, 3.62199850133, 6.294...
# 6000   [0.0, 0.0, 1.38372571133, 3.6614154733, 6.3514...
# 6500   [0.0, 0.0, 1.3988616318, 3.69680670226, 6.4020...
# 7000   [0.0, 0.0, 1.41267156385, 3.72899245193, 6.447...
# 7500   [0.0, 0.0, 1.42539892752, 3.75857565653, 6.489...
# 8000   [0.0, 0.0, 1.43722454612, 3.78600311927, 6.528...
# 8500   [0.0, 0.0, 1.4482841615, 3.81160926392, 6.5641...
# 9000   [0.0, 0.0, 1.45868096232, 3.83564742559, 6.597...
# 9500   [0.0, 0.0, 1.46849455007, 3.85831224103, 6.629...
# 10000  [0.0, 0.0, 1.47778736049, 3.8797556811, 6.6591...
#
#                                                   signal  \
# 0      [4.346, 4.346, 4.346, 4.346, -6.519, 0.0, 0.0,...
# 500    [8.35572042707, 7.3980574211, 6.33351123412, 5...
# 1000   [9.63038474583, 8.12078272293, 6.44214529924, ...
# 1500   [10.5911641091, 8.6573202521, 6.50622712484, 4...
# 2000   [11.3256842378, 9.06018165617, 6.53930991482, ...
# 2500   [11.8963177834, 9.36662387718, 6.55078581261, ...
# 3000   [12.3477250712, 9.60330239689, 6.54733525518, ...
# 3500   [12.7119122972, 9.78929993975, 6.53370385312, ...
# 4000   [13.0118436093, 9.93828919836, 6.51325698594, ...
# 4500   [13.2640206468, 10.0600772648, 6.48837573259, ...
# 5000   [13.4803247817, 10.1617085656, 6.46073951307, ...
# 5500   [13.6693328796, 10.2482525421, 6.43152784091, ...
# 6000   [13.8372571133, 10.3233662178, 6.40156432131, ...
# 6500   [13.988616318, 10.3896960185, 6.37141941364, 1...
# 7000   [14.1267156385, 10.4491648063, 6.34148375339, ...
# 7500   [14.2539892752, 10.5031769425, 6.31202045541, ...
# 8000   [14.3722454612, 10.5527648164, 6.28320241182, ...
# 8500   [14.482841615, 10.5986935707, 6.25513887827, 1...
# 9000   [14.5868096232, 10.6415359719, 6.22789441419, ...
# 9500   [14.6849455007, 10.6817259591, 6.20150236605, ...
# 10000  [14.7778736049, 10.7195969617, 6.17597445618, ...
#
#                                                 variance  \
# 0      [0.0, 0.0, 9.443858e-05, 0.0004353618538, 0.00...
# 500    [0.0, 0.0, 0.000349090319277, 0.00153387232062...
# 1000   [0.0, 0.0, 0.000463721551763, 0.00200377036203...
# 1500   [0.0, 0.0, 0.000560863785925, 0.00239946423693...
# 2000   [0.0, 0.0, 0.000641355617272, 0.00272572823656...
# 2500   [0.0, 0.0, 0.000707611884012, 0.00299314711557...
# 3000   [0.0, 0.0, 0.000762331572165, 0.00321313406015...
# 3500   [0.0, 0.0, 0.000807963571253, 0.00339590045878...
# 4000   [0.0, 0.0, 0.00084654037056, 0.00354985869867,...
# 4500   [0.0, 0.0, 0.00087967121859, 0.00368163887198,...
# 5000   [0.0, 0.0, 0.000908595781099, 0.00379633237463...
# 5500   [0.0, 0.0, 0.000934253306862, 0.00389778783861...
# 6000   [0.0, 0.0, 0.000957348422098, 0.0039888872541,...
# 6500   [0.0, 0.0, 0.000978406932454, 0.00407177794295...
# 7000   [0.0, 0.0, 0.000997820473648, 0.00414805713561...
# 7500   [0.0, 0.0, 0.00101588105129, 0.00421891422456,...
# 8000   [0.0, 0.0, 0.00103280719798, 0.00428523821107,...
# 8500   [0.0, 0.0, 0.00104876350623, 0.00434769778451,...
# 9000   [0.0, 0.0, 0.00106387507491, 0.00440680045963,...
# 9500   [0.0, 0.0, 0.00107823812179, 0.00446293596697,...
# 10000  [0.0, 0.0, 0.00109192774141, 0.0045164079416, ...
#
#                                                 velocity
# 0      [0.0, 0.4346, 0.82574, 1.177766, 1.4945894, 0....
# 500    [0.0, 0.835572042707, 1.49182058055, 1.9759896...
# 1000   [0.0, 0.963038474583, 1.67881289942, 2.1551461...
# 1500   [0.0, 1.05911641091, 1.81893679503, 2.28766582...
# 2000   [0.0, 1.13256842378, 1.92532974702, 2.38672776...
# 2500   [0.0, 1.18963177834, 2.00733098822, 2.46167647...
# 3000   [0.0, 1.23477250712, 2.07162549609, 2.51919647...
# 3500   [0.0, 1.27119122972, 2.12300210072, 2.56407227...
# 4000   [0.0, 1.30118436093, 2.16489484467, 2.59973105...
# 4500   [0.0, 1.32640206468, 2.19976958469, 2.62863019...
# 5000   [0.0, 1.34803247817, 2.22940008692, 2.65253402...
# 5500   [0.0, 1.36693328796, 2.25506521337, 2.67271147...
# 6000   [0.0, 1.38372571133, 2.27768976197, 2.69007721...
# 6500   [0.0, 1.3988616318, 2.29794507047, 2.705292504...
# 7000   [0.0, 1.41267156385, 2.31632088809, 2.71883717...
# 7500   [0.0, 1.42539892752, 2.33317672901, 2.73106110...
# 8000   [0.0, 1.43722454612, 2.34877857315, 2.74222095...
# 8500   [0.0, 1.4482841615, 2.36332510242, 2.75250648,...
# 9000   [0.0, 1.45868096232, 2.37696646327, 2.76205925...
# 9500   [0.0, 1.46849455007, 2.38981769097, 2.77098615...
# 10000  [0.0, 1.47778736049, 2.40196832061, 2.77936893...

# %%
plot_signal(record.signal, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_position(record.position, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_velocity(1000*record.velocity, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %%
plot_variance(record.variance, m.record_each, m.n_iter, m.t_T, m.t_R, m.dt)

# %% [markdown]
# TODO : use dt / begin with bang bang solution OK
#
# TODO :  copy the notebook OK
#
# TODO: put all functions in one script HW.py - use OO a bit like https://github.com/bicv/SHL_scripts/blob/master/shl_scripts/shl_learn.py#L9 - then just use the functions OK
#
# TODO: cache data https://github.com/bicv/SHL_scripts/blob/master/shl_scripts/shl_experiments.py#L161 , just plot ~OK
#
# TODO: explore parameters
#
#
# TODO: apply on aSPEM / generalized coordinates / include delays

# %% [markdown]
# TODO: utiliser un $\lambda$ pour moduler le coût en vitesse (ou est-ce qu'il s'absorbe dans la variance??)

# %% [markdown]
# TODO: montrer que c'est linéaire en $x_T$

# %% [markdown]
# TODO: essayer en rajoutant le biais

# %% [markdown]
# TODO: montrer que c'est  pas linéaire en $x_T$...

# %% [markdown]
# TODO: montrer une trajectoire 2D

# %% [markdown]
# TODO: regarder la "forme" d'une saccade adaptée
